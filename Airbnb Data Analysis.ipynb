# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\surya\anaconda3\lib\site-packages (4.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\surya\anaconda3\lib\site-packages (from pymongo) (2.4.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
import pymongo
import plotly.express as px

# %%
client = pymongo.MongoClient(r"mongodb+srv://Surya:Surya123@cluster0.cnj3obg.mongodb.net/")
db = client["sample_airbnb"]
col = db ["listingsAndReviews"]

# %%
# client = pymongo.MongoClient("mongodb+srv://Surya:Surya123@cluster0.cnj3obg.mongodb.net/?retryWrites=true&w=majority")

# %%
col.find_one()
# Out:
# {'_id': '10082307',
#  'listing_url': 'https://www.airbnb.com/rooms/10082307',
#  'name': 'Double Room en-suite (307)',
#  'summary': 'A standard double room with a queen size double bed and with private bathroom. There is a working table, chair and a shelf. A clean and comfortable room.',
#  'space': '',
#  'description': 'A standard double room with a queen size double bed and with private bathroom. There is a working table, chair and a shelf. A clean and comfortable room.',
#  'neighborhood_overview': '',
#  'notes': '',
#  'transit': '',
#  'access': '',
#  'interaction': '',
#  'house_rules': '',
#  'property_type': 'Apartment',
#  'room_type': 'Private room',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '1',
#  'maximum_nights': '1125',
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'calendar_last_scraped': datetime.datetime(2019, 3, 11, 4, 0),
#  'accommodates': 2,
#  'bedrooms': 1,
#  'beds': 1,
#  'number_of_reviews': 0,
#  'bathrooms': Decimal128('1.0'),
#  'amenities': ['TV',
#   'Internet',
#   'Wifi',
#   'Air conditioning',
#   'Wheelchair accessible',
#   'Doorman',
#   'Elevator',
#   'Family/kid friendly',
#   'Shampoo',
#   'Hangers',
#   'Hair dryer',
#   'Iron'],
#  'price': Decimal128('361.00'),
#  'extra_people': Decimal128('130.00'),
#  'guests_included': Decimal128('2'),
#  'images': {'thumbnail_url': '',
#   'medium_url': '',
#   'picture_url': 'https://a0.muscache.com/im/pictures/8ee32fb6-2094-42ee-ae6c-ff40b479f9a7.jpg?aki_policy=large',
#   'xl_picture_url': ''},
#  'host': {'host_id': '51289938',
#   'host_url': 'https://www.airbnb.com/users/show/51289938',
#   'host_name': 'Ken',
#   'host_location': 'Hong Kong',
#   'host_about': 'Out-going and positive. Happy to talk to guests and exchange our difference in culture.',
#   'host_response_time': 'within an hour',
#   'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/48ba1de1-bfea-446c-83ab-c21cb4272696.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a0.muscache.com/im/pictures/48ba1de1-bfea-446c-83ab-c21cb4272696.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': 'Jordan',
#   'host_response_rate': 90,
#   'host_is_superhost': False,
#   'host_has_profile_pic': True,
#   'host_identity_verified': False,
#   'host_listings_count': 6,
#   'host_total_listings_count': 6,
#   'host_verifications': ['email', 'phone', 'google', 'reviews']},
#  'address': {'street': 'Hong Kong, Kowloon, Hong Kong',
#   'suburb': 'Yau Tsim Mong',
#   'government_area': 'Yau Tsim Mong',
#   'market': 'Hong Kong',
#   'country': 'Hong Kong',
#   'country_code': 'HK',
#   'location': {'type': 'Point',
#    'coordinates': [114.17158, 22.30469],
#    'is_location_exact': True}},
#  'availability': {'availability_30': 30,
#   'availability_60': 60,
#   'availability_90': 90,
#   'availability_365': 365},
#  'review_scores': {},
#  'reviews': []}

# %%
data = []
for i in col.find():
    data2 = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i.get('name'),
                Description = i['description'],
                House_rules = i.get('house_rules'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Availability_365 = i['availability']['availability_365'],
                Price = i['price'],
                Country = i['address']['country'],
                Min_night = int(i['minimum_nights']),
                Max_night = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                Bed_type = i['bed_type'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Street = i['address']['street'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact']
    )
    data.append(data2)

# %%
air = pd.DataFrame(data)
air
# Out:
#             Id                            Listing_url  \
# 0     10082307  https://www.airbnb.com/rooms/10082307
# 1     10059872  https://www.airbnb.com/rooms/10059872
# 2     10057447  https://www.airbnb.com/rooms/10057447
# 3     10038496  https://www.airbnb.com/rooms/10038496
# 4     10006546  https://www.airbnb.com/rooms/10006546
# ...        ...                                    ...
# 5550   9867316   https://www.airbnb.com/rooms/9867316
# 5551   9979991   https://www.airbnb.com/rooms/9979991
# 5552   9993190   https://www.airbnb.com/rooms/9993190
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9951865   https://www.airbnb.com/rooms/9951865
#
#                                                    Name  \
# 0                            Double Room en-suite (307)
# 1                    Soho Cozy, Spacious and Convenient
# 2                        Modern Spacious 1 Bedroom Loft
# 3                          Copacabana Apartment Posto 6
# 4                               Ribeira Charming Duplex
# ...                                                 ...
# 5550         Beautiful Place in the Middle of Manhattan
# 5551
# 5552  Just Steps from the Ocean at Premier Platinum ...
# 5553                         Large double room in Bondi
# 5554                                       Quarto Legal
#
#                                             Description  \
# 0     A standard double room with a queen size doubl...
# 1     Clean, fully furnish, Spacious 1 bedroom flat ...
# 2     Prime location, amazing lighting and no annoyi...
# 3     The Apartment has a living room, toilet, bedro...
# 4     Fantastic duplex apartment with three bedrooms...
# ...                                                 ...
# 5550  Beautiful place only a couple blocks from main...
# 5551  Located at the heart of Kowloon, our unit is s...
# 5552  Relax Hawaiian Style in Gated Community on Oce...
# 5553  A bright large double room is available in a b...
# 5554  Meu espaço é perto de Cristo Redentor, Copacab...
#
#                                             House_rules Property_type  \
# 0                                                           Apartment
# 1                                                           Apartment
# 2                                                           Apartment
# 3     Entreguem o imóvel conforme receberam e respei...     Apartment
# 4                           Make the house your home...         House
# ...                                                 ...           ...
# 5550  1. NO smoking 2. NO outside guests 3. Please t...     Apartment
# 5551                                                        Apartment
# 5552  As a guest of Coconut Condos, I agree to the f...     Townhouse
# 5553  We like to keep the flat clean and tidy so wou...     Apartment
# 5554                                                        Apartment
#
#             Room_type  Availability_365    Price        Country  ...  \
# 0        Private room               365   361.00      Hong Kong  ...
# 1     Entire home/apt                 0   699.00      Hong Kong  ...
# 2     Entire home/apt                 0    50.00         Canada  ...
# 3     Entire home/apt               118   119.00         Brazil  ...
# 4     Entire home/apt               239    80.00       Portugal  ...
# ...               ...               ...      ...            ...  ...
# 5550  Entire home/apt               154   160.00  United States  ...
# 5551  Entire home/apt                 0  1052.00      Hong Kong  ...
# 5552  Entire home/apt               258   220.00  United States  ...
# 5553     Private room                 0    60.00      Australia  ...
# 5554     Private room               365   101.00         Brazil  ...
#
#       Review_scores                                          Amenities  \
# 0               NaN  TV, Internet, Wifi, Air conditioning, Wheelcha...
# 1             100.0  Air conditioning, Kitchen, Smoking allowed, Do...
# 2               NaN  Internet, Wifi, Kitchen, Heating, Family/kid f...
# 3              98.0  TV, Cable TV, Internet, Wifi, Air conditioning...
# 4              89.0  TV, Cable TV, Wifi, Kitchen, Paid parking off ...
# ...             ...                                                ...
# 5550           92.0  Wifi, Air conditioning, Kitchen, Pets allowed,...
# 5551            NaN  TV, Internet, Air conditioning, Kitchen, Eleva...
# 5552           92.0  TV, Wifi, Air conditioning, Pool, Kitchen, Fre...
# 5553            NaN  TV, Internet, Wifi, Kitchen, Washer, Dryer, Sm...
# 5554          100.0  TV, Wifi, Kitchen, Gym, Elevator, Free street ...
#
#        Host_id       Host_name  \
# 0     51289938             Ken
# 1     51624384        Giovanni
# 2     51612949      Konstantin
# 3     51530266     Ana Valéria
# 4     51399391     Ana&Gonçalo
# ...        ...             ...
# 5550  40540485          Miguel
# 5551  51283546          Alexis
# 5552  51013381  Coconut Condos
# 5553  47615848            Lucy
# 5554  51142039         Dailton
#
#                                                Street  Country_code  \
# 0                       Hong Kong, Kowloon, Hong Kong            HK
# 1              Hong Kong, Hong Kong Island, Hong Kong            HK
# 2                            Montréal, Québec, Canada            CA
# 3              Rio de Janeiro, Rio de Janeiro, Brazil            BR
# 4                              Porto, Porto, Portugal            PT
# ...                                               ...           ...
# 5550                      New York, NY, United States            US
# 5551                    Hong Kong, Kowloon, Hong Kong            HK
# 5552                       Lahaina, HI, United States            US
# 5553                      Bondi Beach, NSW, Australia            AU
# 5554  Rio de Janeiro, State of Rio de Janeiro, Brazil            BR
#
#      Location_type   Longitude   Latitude Is_location_exact
# 0            Point  114.171580  22.304690              True
# 1            Point  114.150270  22.281580              True
# 2            Point  -73.591110  45.518890              True
# 3            Point  -43.190849 -22.984339             False
# 4            Point   -8.613080  41.141300             False
# ...            ...         ...        ...               ...
# 5550         Point  -73.962050  40.762660              True
# 5551         Point  114.169630  22.315690             False
# 5552         Point -156.667520  20.858940             False
# 5553         Point  151.265420 -33.892980             False
# 5554         Point  -43.210667 -22.918155             False
#
# [5555 rows x 32 columns]

# %%
air["Room_type"].value_counts()
# Out:
# Entire home/apt    3489
# Private room       1983
# Shared room          83
# Name: Room_type, dtype: int64

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Availability_365     5555 non-null   int64
#  8   Price                5555 non-null   object
#  9   Country              5555 non-null   object
#  10  Min_night            5555 non-null   int64
#  11  Max_night            5555 non-null   int64
#  12  Cancellation_policy  5555 non-null   object
#  13  Accomodates          5555 non-null   int64
#  14  Total_bedrooms       5550 non-null   float64
#  15  Total_beds           5542 non-null   float64
#  16  Bed_type             5555 non-null   object
#  17  Security_deposit     3471 non-null   object
#  18  Cleaning_fee         4024 non-null   object
#  19  Extra_people         5555 non-null   object
#  20  Guests_included      5555 non-null   object
#  21  No_of_reviews        5555 non-null   int64
#  22  Review_scores        4081 non-null   float64
#  23  Amenities            5555 non-null   object
#  24  Host_id              5555 non-null   object
#  25  Host_name            5555 non-null   object
#  26  Street               5555 non-null   object
#  27  Country_code         5555 non-null   object
#  28  Location_type        5555 non-null   object
#  29  Longitude            5555 non-null   float64
#  30  Latitude             5555 non-null   float64
#  31  Is_location_exact    5555 non-null   bool
# dtypes: bool(1), float64(5), int64(5), object(21)
# memory usage: 1.3+ MB

# %%
air.isnull().sum()
# Out:
# Id                     0
# Listing_url            0
# Name                   0
# Description            0
# House_rules            0
# Property_type          0
# Room_type              0
# Availability_365       0
# Price                  0
# Country                0
# Min_night              0
# Max_night              0
# Cancellation_policy    0
# Accomodates            0
# Total_bedrooms         0
# Total_beds             0
# Bed_type               0
# Security_deposit       0
# Cleaning_fee           0
# Extra_people           0
# Guests_included        0
# No_of_reviews          0
# Review_scores          0
# Amenities              0
# Host_id                0
# Host_name              0
# Street                 0
# Country_code           0
# Location_type          0
# Longitude              0
# Latitude               0
# Is_location_exact      0
# dtype: int64

# %%
air.describe()
# Out:
#        Availability_365    Min_night     Max_night  Accomodates  \
# count       5555.000000  5555.000000  5.555000e+03  5555.000000
# mean         173.105671     5.564356  1.382776e+06     3.505851
# std          139.841893    22.613861  5.256920e+07     2.297019
# min            0.000000     1.000000  1.000000e+00     1.000000
# 25%           17.000000     1.000000  5.900000e+01     2.000000
# 50%          171.000000     2.000000  1.125000e+03     3.000000
# 75%          317.000000     3.000000  1.125000e+03     4.000000
# max          365.000000  1250.000000  2.147484e+09    16.000000
#
#        Total_bedrooms   Total_beds  No_of_reviews  Review_scores    Longitude  \
# count     5550.000000  5542.000000    5555.000000    4081.000000  5555.000000
# mean         1.411712     2.071454      27.606481      93.099240    -6.623240
# std          1.041942     1.619660      49.798376       9.023483    90.525974
# min          0.000000     0.000000       0.000000      20.000000  -159.678690
# 25%          1.000000     1.000000       1.000000      90.000000   -73.599530
# 50%          1.000000     2.000000       5.000000      95.000000    -8.611420
# 75%          2.000000     3.000000      32.000000      99.000000    29.019605
# max         20.000000    25.000000     533.000000     100.000000   151.338980
#
#           Latitude
# count  5555.000000
# mean     22.061230
# std      28.092112
# min     -34.088290
# 25%      20.724390
# 50%      40.727130
# 75%      41.162755
# max      45.665630

# %%
air.shape
# Out:
# (5555, 32)

# %%
air['Price'] = air['Price'].astype(str).astype(float)
air['Security_deposit'] = air['Security_deposit'][~air['Security_deposit'].isna()].astype(str).astype(float)
air['Cleaning_fee'] = air['Cleaning_fee'][~air['Cleaning_fee'].isna()].astype(str).astype(float)
air['Extra_people'] = air['Extra_people'].astype(str).astype(float)
air['Review_scores'] = air['Review_scores'].astype('Int64')
air['Guests_included'] = air['Guests_included'].astype(str).astype(float)

# %%
air.shape
# Out:
# (5555, 32)

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Availability_365     5555 non-null   int64
#  8   Price                5555 non-null   float64
#  9   Country              5555 non-null   object
#  10  Min_night            5555 non-null   int64
#  11  Max_night            5555 non-null   int64
#  12  Cancellation_policy  5555 non-null   object
#  13  Accomodates          5555 non-null   int64
#  14  Total_bedrooms       5555 non-null   float64
#  15  Total_beds           5555 non-null   float64
#  16  Bed_type             5555 non-null   object
#  17  Security_deposit     5555 non-null   float64
#  18  Cleaning_fee         5555 non-null   float64
#  19  Extra_people         5555 non-null   float64
#  20  Guests_included      5555 non-null   float64
#  21  No_of_reviews        5555 non-null   int64
#  22  Review_scores        5555 non-null   Int64
#  23  Amenities            5555 non-null   object
#  24  Host_id              5555 non-null   object
#  25  Host_name            5555 non-null   object
#  26  Street               5555 non-null   object
#  27  Country_code         5555 non-null   object
#  28  Location_type        5555 non-null   object
#  29  Longitude            5555 non-null   float64
#  30  Latitude             5555 non-null   float64
#  31  Is_location_exact    5555 non-null   bool
# dtypes: Int64(1), bool(1), float64(9), int64(5), object(16)
# memory usage: 1.3+ MB

# %%
air.Total_bedrooms.fillna(air.Total_bedrooms.median(),inplace=True)
air.Total_beds.fillna(air.Total_beds.median(),inplace=True)
air.Security_deposit.fillna(air.Security_deposit.median(),inplace=True)
air.Cleaning_fee.fillna(air.Cleaning_fee.median(),inplace=True)
air.Review_scores.fillna(air.Review_scores.median(),inplace=True)

# %%
air.drop(labels=list(air[air['Name'].duplicated(keep=False)].index),inplace=True)
air.reset_index(drop=True,inplace=True)

# %%
air.shape
# Out:
# (5529, 32)

# %%
air.to_csv(r'C:\Users\surya\Desktop\New folder (4)\airbnb\Airbnb_data.csv',index=False)
